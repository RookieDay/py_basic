# %%
# 导入 matplotlib 的所有内容（nympy 可以用 np 这个名字来使用）
import matplotlib.pyplot as plt

# 创建一个 8 * 6 点（point）的图，并设置分辨率为 80
plt.figure(figsize=(10,6), dpi=80)

# 创建一个新的 1 * 1 的子图，接下来的图样绘制在其中的第 1 块（也是唯一的一块）
plt.subplot(1,1,1)

X = np.linspace(-np.pi, np.pi, 256,endpoint=True)
C,S = np.cos(X), np.sin(X)

# 绘制余弦曲线，使用蓝色的、连续的、宽度为 1 （像素）的线条
plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-",label="consine")

# 绘制正弦曲线，使用绿色的、连续的、宽度为 1 （像素）的线条
plt.plot(X, S, color="green", linewidth=2.5, linestyle="-",label="sine")

# 绘制图例
plt.legend(loc='upper left')

# 设置横轴的上下限
plt.xlim(-4.0,4.0)

# 设置横轴记号
plt.xticks(np.linspace(-4,4,9,endpoint=True))

# 设置纵轴的上下限
plt.ylim(-1.0,1.0)

# 设置纵轴记号
plt.yticks(np.linspace(-1,2,5,endpoint=True))

# 以分辨率 72 来保存图片
# savefig("exercice_2.png",dpi=72)

# 在屏幕上显示
plt.show()

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)
plt.plot(X,Y+1,color='blue',alpha=1.00)
plt.plot(X,Y-1,color='blue',alpha=1.00)
plt.show()

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

plt.scatter(X,Y)
plt.show()

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%cmd  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %whos
# Out:
# Variable                     Type                          Data/Info
# --------------------------------------------------------------------
# ALLOW_THREADS                int                           1
# Annotation                   type                          <class 'matplotlib.text.Annotation'>
# Arrow                        type                          <class 'matplotlib.patches.Arrow'>
# Artist                       type                          <class 'matplotlib.artist.Artist'>
# AutoLocator                  type                          <class 'matplotlib.ticker.AutoLocator'>
# Axes                         type                          <class 'matplotlib.axes._axes.Axes'>
# AxisError                    type                          <class 'numpy.core._internal.AxisError'>
# BUFSIZE                      int                           8192
# Button                       type                          <class 'matplotlib.widgets.Button'>
# C                            ndarray                       256: 256 elems, type `float64`, 2048 bytes
# CLIP                         int                           0
# Circle                       type                          <class 'matplotlib.patches.Circle'>
# ComplexWarning               type                          <class 'numpy.core.numeric.ComplexWarning'>
# DAILY                        int                           3
# DataSource                   type                          <class 'numpy.lib._datasource.DataSource'>
# DateFormatter                type                          <class 'matplotlib.dates.DateFormatter'>
# DateLocator                  type                          <class 'matplotlib.dates.DateLocator'>
# DayLocator                   type                          <class 'matplotlib.dates.DayLocator'>
# ERR_CALL                     int                           3
# ERR_DEFAULT                  int                           521
# ERR_IGNORE                   int                           0
# ERR_LOG                      int                           5
# ERR_PRINT                    int                           4
# ERR_RAISE                    int                           2
# ERR_WARN                     int                           1
# FLOATING_POINT_SUPPORT       int                           1
# FPE_DIVIDEBYZERO             int                           1
# FPE_INVALID                  int                           8
# FPE_OVERFLOW                 int                           2
# FPE_UNDERFLOW                int                           4
# FR                           weekday                       FR
# False_                       bool_                         False
# Figure                       type                          <class 'matplotlib.figure.Figure'>
# FigureCanvasBase             type                          <class 'matplotlib.backen<...>_bases.FigureCanvasBase'>
# FixedFormatter               type                          <class 'matplotlib.ticker.FixedFormatter'>
# FixedLocator                 type                          <class 'matplotlib.ticker.FixedLocator'>
# FormatStrFormatter           type                          <class 'matplotlib.ticker.FormatStrFormatter'>
# Formatter                    type                          <class 'matplotlib.ticker.Formatter'>
# FuncFormatter                type                          <class 'matplotlib.ticker.FuncFormatter'>
# GridSpec                     type                          <class 'matplotlib.gridspec.GridSpec'>
# HOURLY                       int                           4
# HourLocator                  type                          <class 'matplotlib.dates.HourLocator'>
# IndexDateFormatter           type                          <class 'matplotlib.dates.IndexDateFormatter'>
# IndexLocator                 type                          <class 'matplotlib.ticker.IndexLocator'>
# Inf                          float                         inf
# Infinity                     float                         inf
# LinAlgError                  type                          <class 'numpy.linalg.linalg.LinAlgError'>
# Line2D                       type                          <class 'matplotlib.lines.Line2D'>
# LinearLocator                type                          <class 'matplotlib.ticker.LinearLocator'>
# Locator                      type                          <class 'matplotlib.ticker.Locator'>
# LogFormatter                 type                          <class 'matplotlib.ticker.LogFormatter'>
# LogFormatterExponent         type                          <class 'matplotlib.ticker.LogFormatterExponent'>
# LogFormatterMathtext         type                          <class 'matplotlib.ticker.LogFormatterMathtext'>
# LogLocator                   type                          <class 'matplotlib.ticker.LogLocator'>
# MAXDIMS                      int                           32
# MAY_SHARE_BOUNDS             int                           0
# MAY_SHARE_EXACT              int                           -1
# MINUTELY                     int                           5
# MO                           weekday                       MO
# MONTHLY                      int                           1
# MachAr                       type                          <class 'numpy.core.machar.MachAr'>
# MaxNLocator                  type                          <class 'matplotlib.ticker.MaxNLocator'>
# MinuteLocator                type                          <class 'matplotlib.dates.MinuteLocator'>
# ModuleDeprecationWarning     type                          <class 'numpy._globals.ModuleDeprecationWarning'>
# MonthLocator                 type                          <class 'matplotlib.dates.MonthLocator'>
# MultipleLocator              type                          <class 'matplotlib.ticker.MultipleLocator'>
# NAN                          float                         nan
# NINF                         float                         -inf
# NZERO                        float                         -0.0
# NaN                          float                         nan
# Normalize                    type                          <class 'matplotlib.colors.Normalize'>
# NullFormatter                type                          <class 'matplotlib.ticker.NullFormatter'>
# NullLocator                  type                          <class 'matplotlib.ticker.NullLocator'>
# PINF                         float                         inf
# PZERO                        float                         0.0
# PackageLoader                type                          <class 'numpy._import_tools.PackageLoader'>
# PolarAxes                    type                          <class 'matplotlib.projections.polar.PolarAxes'>
# Polygon                      type                          <class 'matplotlib.patches.Polygon'>
# RAISE                        int                           2
# RRuleLocator                 type                          <class 'matplotlib.dates.RRuleLocator'>
# RankWarning                  type                          <class 'numpy.lib.polynomial.RankWarning'>
# Rectangle                    type                          <class 'matplotlib.patches.Rectangle'>
# S                            ndarray                       256: 256 elems, type `float64`, 2048 bytes
# SA                           weekday                       SA
# SECONDLY                     int                           6
# SHIFT_DIVIDEBYZERO           int                           0
# SHIFT_INVALID                int                           9
# SHIFT_OVERFLOW               int                           3
# SHIFT_UNDERFLOW              int                           6
# SU                           weekday                       SU
# ScalarFormatter              type                          <class 'matplotlib.ticker.ScalarFormatter'>
# ScalarType                   tuple                         n=32
# SecondLocator                type                          <class 'matplotlib.dates.SecondLocator'>
# Slider                       type                          <class 'matplotlib.widgets.Slider'>
# Subplot                      type                          <class 'matplotlib.axes._subplots.AxesSubplot'>
# SubplotTool                  type                          <class 'matplotlib.widgets.SubplotTool'>
# TH                           weekday                       TH
# TU                           weekday                       TU
# Text                         type                          <class 'matplotlib.text.Text'>
# TickHelper                   type                          <class 'matplotlib.ticker.TickHelper'>
# TooHardError                 type                          <class 'numpy.core._internal.TooHardError'>
# True_                        bool_                         True
# UFUNC_BUFSIZE_DEFAULT        int                           8192
# UFUNC_PYVALS_NAME            str                           UFUNC_PYVALS
# VisibleDeprecationWarning    type                          <class 'numpy._globals.Vi<...>sibleDeprecationWarning'>
# WE                           weekday                       WE
# WEEKLY                       int                           2
# WRAP                         int                           1
# WeekdayLocator               type                          <class 'matplotlib.dates.WeekdayLocator'>
# Widget                       type                          <class 'matplotlib.widgets.Widget'>
# X                            ndarray                       1024: 1024 elems, type `float64`, 8192 bytes
# Y                            ndarray                       1024: 1024 elems, type `float64`, 8192 bytes
# YEARLY                       int                           0
# YearLocator                  type                          <class 'matplotlib.dates.YearLocator'>
# absolute                     ufunc                         <ufunc 'absolute'>
# absolute_import              _Feature                      _Feature((2, 5, 0, 'alpha<...>0, 0, 'alpha', 0), 16384)
# acorr                        function                      <function acorr at 0x000000000E1DAEA0>
# add                          ufunc                         <ufunc 'add'>
# add_docstring                builtin_function_or_method    <built-in function add_docstring>
# add_newdoc                   function                      <function add_newdoc at 0x0000000005295C80>
# add_newdoc_ufunc             builtin_function_or_method    <built-in function _add_newdoc_ufunc>
# add_newdocs                  module                        <module 'numpy.add_newdoc<...>\\numpy\\add_newdocs.py'>
# alen                         function                      <function alen at 0x0000000004FB79D8>
# all                          function                      <function all at 0x0000000004FB76A8>
# allclose                     function                      <function allclose at 0x0000000004FBA840>
# alltrue                      function                      <function alltrue at 0x0000000004FB7598>
# amap                         function                      <function amap at 0x00000000075E2EA0>
# amax                         function                      <function amax at 0x0000000004FB78C8>
# amin                         function                      <function amin at 0x0000000004FB7950>
# angle                        function                      <function angle at 0x00000000052947B8>
# angle_spectrum               function                      <function angle_spectrum at 0x000000000E1DAF28>
# annotate                     function                      <function annotate at 0x000000000E1DEEA0>
# any                          function                      <function any at 0x0000000004FB7620>
# append                       function                      <function append at 0x0000000005295EA0>
# apply_along_axis             function                      <function apply_along_axis at 0x00000000052A7F28>
# apply_over_axes              function                      <function apply_over_axes at 0x00000000052B60D0>
# arange                       builtin_function_or_method    <built-in function arange>
# arccos                       ufunc                         <ufunc 'arccos'>
# arccosh                      ufunc                         <ufunc 'arccosh'>
# arcsin                       ufunc                         <ufunc 'arcsin'>
# arcsinh                      ufunc                         <ufunc 'arcsinh'>
# arctan                       ufunc                         <ufunc 'arctan'>
# arctan2                      ufunc                         <ufunc 'arctan2'>
# arctanh                      ufunc                         <ufunc 'arctanh'>
# argmax                       function                      <function argmax at 0x0000000004FB4D08>
# argmin                       function                      <function argmin at 0x0000000004FB4D90>
# argpartition                 function                      <function argpartition at 0x0000000004FB4B70>
# argsort                      function                      <function argsort at 0x0000000004FB4C80>
# argwhere                     function                      <function argwhere at 0x0000000004F9B488>
# around                       function                      <function around at 0x0000000004FB7D08>
# array                        builtin_function_or_method    <built-in function array>
# array2string                 function                      <function array2string at 0x0000000004FB86A8>
# array_equal                  function                      <function array_equal at 0x0000000004FBA950>
# array_equiv                  function                      <function array_equiv at 0x0000000004FBA9D8>
# array_repr                   function                      <function array_repr at 0x0000000004F9BB70>
# array_split                  function                      <function array_split at 0x00000000052B6378>
# array_str                    function                      <function array_str at 0x0000000004FB89D8>
# arrow                        function                      <function arrow at 0x000000000E1DD048>
# asanyarray                   function                      <function asanyarray at 0x0000000004F9B1E0>
# asarray                      function                      <function asarray at 0x0000000004F9B158>
# asarray_chkfinite            function                      <function asarray_chkfini<...>te at 0x0000000005294400>
# ascontiguousarray            function                      <function ascontiguousarr<...>ay at 0x0000000004F9B268>
# asfarray                     function                      <function asfarray at 0x00000000052732F0>
# asfortranarray               function                      <function asfortranarray at 0x0000000004F9B2F0>
# asmatrix                     function                      <function asmatrix at 0x0000000005297268>
# asscalar                     function                      <function asscalar at 0x0000000005273840>
# atleast_1d                   function                      <function atleast_1d at 0x0000000004FE99D8>
# atleast_2d                   function                      <function atleast_2d at 0x0000000004FE9488>
# atleast_3d                   function                      <function atleast_3d at 0x0000000004FE9A60>
# autoscale                    function                      <function autoscale at 0x000000000E1E01E0>
# autumn                       function                      <function autumn at 0x000000000E1DAE18>
# average                      function                      <function average at 0x0000000005294378>
# axes                         function                      <function axes at 0x000000000E1D92F0>
# axhline                      function                      <function axhline at 0x000000000E1DD0D0>
# axhspan                      function                      <function axhspan at 0x000000000E1DD158>
# axis                         function                      <function axis at 0x000000000E1D9D90>
# axvline                      function                      <function axvline at 0x000000000E1DD1E0>
# axvspan                      function                      <function axvspan at 0x000000000E1DD268>
# bar                          function                      <function bar at 0x000000000E1DD2F0>
# barbs                        function                      <function barbs at 0x000000000E1DEB70>
# barh                         function                      <function barh at 0x000000000E1DD378>
# bartlett                     function                      <function bartlett at 0x0000000005295400>
# base_repr                    function                      <function base_repr at 0x0000000004FBA620>
# bench                        method                        <bound method NoseTester.<...>t at 0x00000000052BE940>>
# beta                         builtin_function_or_method    <built-in method beta of <...>ct at 0x000000000557D168>
# binary_repr                  function                      <function binary_repr at 0x0000000004FBA598>
# bincount                     builtin_function_or_method    <built-in function bincount>
# binomial                     builtin_function_or_method    <built-in method binomial<...>ct at 0x000000000557D168>
# bitwise_and                  ufunc                         <ufunc 'bitwise_and'>
# bitwise_not                  ufunc                         <ufunc 'invert'>
# bitwise_or                   ufunc                         <ufunc 'bitwise_or'>
# bitwise_xor                  ufunc                         <ufunc 'bitwise_xor'>
# bivariate_normal             function                      <function bivariate_normal at 0x00000000075E29D8>
# blackman                     function                      <function blackman at 0x0000000005295378>
# block                        function                      <function block at 0x0000000004FE9C80>
# bmat                         function                      <function bmat at 0x000000000529E6A8>
# bone                         function                      <function bone at 0x000000000E1E0268>
# bool8                        type                          <class 'numpy.bool_'>
# bool_                        type                          <class 'numpy.bool_'>
# box                          function                      <function box at 0x000000000E1D9C80>
# boxplot                      function                      <function boxplot at 0x000000000E1DD488>
# broadcast                    type                          <class 'numpy.broadcast'>
# broadcast_arrays             function                      <function broadcast_arrays at 0x000000000529E9D8>
# broadcast_to                 function                      <function broadcast_to at 0x000000000529E8C8>
# broken_barh                  function                      <function broken_barh at 0x000000000E1DD400>
# busday_count                 builtin_function_or_method    <built-in function busday_count>
# busday_offset                builtin_function_or_method    <built-in function busday_offset>
# busdaycalendar               type                          <class 'numpy.busdaycalendar'>
# byte                         type                          <class 'numpy.int8'>
# byte_bounds                  function                      <function byte_bounds at 0x00000000052587B8>
# bytes                        type                          <class 'bytes'>
# bytes0                       type                          <class 'numpy.bytes_'>
# bytes_                       type                          <class 'numpy.bytes_'>
# c_                           CClass                        <numpy.lib.index_tricks.C<...>ct at 0x00000000052A10F0>
# can_cast                     builtin_function_or_method    <built-in function can_cast>
# cast                         _typedict                     {<class 'numpy.complex128<...>> at 0x0000000004F8B730>}
# cbook                        module                        <module 'matplotlib.cbook<...>lib\\cbook\\__init__.py'>
# cbrt                         ufunc                         <ufunc 'cbrt'>
# cdouble                      type                          <class 'numpy.complex128'>
# ceil                         ufunc                         <ufunc 'ceil'>
# center_matrix                function                      <function center_matrix at 0x00000000075E28C8>
# cfloat                       type                          <class 'numpy.complex128'>
# char                         module                        <module 'numpy.core.defch<...>\\core\\defchararray.py'>
# character                    type                          <class 'numpy.character'>
# chararray                    type                          <class 'numpy.core.defchararray.chararray'>
# chisquare                    builtin_function_or_method    <built-in method chisquar<...>ct at 0x000000000557D168>
# choice                       builtin_function_or_method    <built-in method choice o<...>ct at 0x000000000557D168>
# cholesky                     function                      <function cholesky at 0x00000000052CE510>
# choose                       function                      <function choose at 0x0000000004FB4840>
# cla                          function                      <function cla at 0x000000000E1DEBF8>
# clabel                       function                      <function clabel at 0x000000000E1DD598>
# clf                          function                      <function clf at 0x000000000E1D8D90>
# clim                         function                      <function clim at 0x000000000E1DA8C8>
# clip                         function                      <function clip at 0x0000000004FB7378>
# clongdouble                  type                          <class 'numpy.complex128'>
# clongfloat                   type                          <class 'numpy.complex128'>
# close                        function                      <function close at 0x000000000E1D8BF8>
# cm                           module                        <module 'matplotlib.cm' f<...>ages\\matplotlib\\cm.py'>
# cohere                       function                      <function cohere at 0x000000000E1DD510>
# colorbar                     function                      <function colorbar at 0x000000000E1DA840>
# colormaps                    function                      <function colormaps at 0x000000000E1DA620>
# colors                       function                      <function colors at 0x000000000E1DA7B8>
# column_stack                 function                      <function column_stack at 0x00000000052B61E0>
# common_type                  function                      <function common_type at 0x0000000005273950>
# compare_chararrays           builtin_function_or_method    <built-in function compare_chararrays>
# complex128                   type                          <class 'numpy.complex128'>
# complex64                    type                          <class 'numpy.complex64'>
# complex_                     type                          <class 'numpy.complex128'>
# complexfloating              type                          <class 'numpy.complexfloating'>
# compress                     function                      <function compress at 0x0000000004FB72F0>
# concatenate                  builtin_function_or_method    <built-in function concatenate>
# cond                         function                      <function cond at 0x00000000052CE950>
# conj                         ufunc                         <ufunc 'conjugate'>
# conjugate                    ufunc                         <ufunc 'conjugate'>
# connect                      function                      <function connect at 0x000000000E1D8C80>
# contour                      function                      <function contour at 0x000000000E1DD620>
# contourf                     function                      <function contourf at 0x000000000E1DD6A8>
# convolve                     function                      <function convolve at 0x0000000004F9B6A8>
# cool                         function                      <function cool at 0x000000000E1E02F0>
# copper                       function                      <function copper at 0x000000000E1E0378>
# copy                         function                      <function copy at 0x0000000005294598>
# copysign                     ufunc                         <ufunc 'copysign'>
# copyto                       builtin_function_or_method    <built-in function copyto>
# corrcoef                     function                      <function corrcoef at 0x00000000052952F0>
# correlate                    function                      <function correlate at 0x0000000004F9B620>
# cos                          ufunc                         <ufunc 'cos'>
# cosh                         ufunc                         <ufunc 'cosh'>
# count_nonzero                function                      <function count_nonzero at 0x0000000004F9B0D0>
# cov                          function                      <function cov at 0x0000000005294F28>
# cross                        function                      <function cross at 0x0000000004F9BAE8>
# csd                          function                      <function csd at 0x000000000E1DD730>
# csingle                      type                          <class 'numpy.complex64'>
# csv2rec                      function                      <function csv2rec at 0x00000000075E3A60>
# ctypeslib                    module                        <module 'numpy.ctypeslib'<...>es\\numpy\\ctypeslib.py'>
# cumprod                      function                      <function cumprod at 0x0000000004FB7AE8>
# cumproduct                   function                      <function cumproduct at 0x0000000004FB77B8>
# cumsum                       function                      <function cumsum at 0x0000000004FB7730>
# cycler                       function                      <function cycler at 0x00000000059678C8>
# date2num                     function                      <function date2num at 0x00000000070D1E18>
# datestr2num                  function                      <function datestr2num at 0x00000000070D1B70>
# datetime                     module                        <module 'datetime' from '<...>hon35\\lib\\datetime.py'>
# datetime64                   type                          <class 'numpy.datetime64'>
# datetime_as_string           builtin_function_or_method    <built-in function datetime_as_string>
# datetime_data                builtin_function_or_method    <built-in function datetime_data>
# dedent                       function                      <function dedent at 0x00000000055F5598>
# deg2rad                      ufunc                         <ufunc 'deg2rad'>
# degrees                      ufunc                         <ufunc 'degrees'>
# delaxes                      function                      <function delaxes at 0x000000000E1D9620>
# delete                       function                      <function delete at 0x0000000005295D90>
# demean                       function                      <function demean at 0x00000000075DE8C8>
# deprecate                    function                      <function deprecate at 0x0000000005258510>
# deprecate_with_doc           function                      <function <lambda> at 0x0000000005258730>
# deprecated                   function                      <function deprecated at 0x0000000004D16048>
# det                          function                      <function det at 0x00000000052CEB70>
# detrend                      function                      <function detrend at 0x00000000075DE840>
# detrend_linear               function                      <function detrend_linear at 0x00000000075DEA60>
# detrend_mean                 function                      <function detrend_mean at 0x00000000075DE950>
# detrend_none                 function                      <function detrend_none at 0x00000000075DE9D8>
# diag                         function                      <function diag at 0x00000000052856A8>
# diag_indices                 function                      <function diag_indices at 0x00000000052A2488>
# diag_indices_from            function                      <function diag_indices_fr<...>om at 0x00000000052A2510>
# diagflat                     function                      <function diagflat at 0x0000000005285730>
# diagonal                     function                      <function diagonal at 0x0000000004FB7048>
# diff                         function                      <function diff at 0x00000000052946A8>
# digitize                     builtin_function_or_method    <built-in function digitize>
# dirichlet                    builtin_function_or_method    <built-in method dirichle<...>ct at 0x000000000557D168>
# disconnect                   function                      <function disconnect at 0x000000000E1D8D08>
# disp                         function                      <function disp at 0x0000000005294BF8>
# dist                         function                      <function dist at 0x00000000075E2B70>
# dist_point_to_segment        function                      <function dist_point_to_s<...>nt at 0x00000000075E2BF8>
# distances_along_curve        function                      <function distances_along<...>ve at 0x00000000075E5400>
# divide                       ufunc                         <ufunc 'true_divide'>
# division                     _Feature                      _Feature((2, 2, 0, 'alpha<...> 0, 0, 'alpha', 0), 8192)
# divmod                       ufunc                         <ufunc 'divmod'>
# docstring                    module                        <module 'matplotlib.docst<...>atplotlib\\docstring.py'>
# dot                          builtin_function_or_method    <built-in function dot>
# double                       type                          <class 'numpy.float64'>
# drange                       function                      <function drange at 0x00000000070C21E0>
# draw                         function                      <function draw at 0x000000000E1D8E18>
# draw_all                     method                        <bound method Gcf.draw_al<...>lib._pylab_helpers.Gcf'>>
# draw_if_interactive          function                      <function draw_if_interac<...>ve at 0x000000000E1D0B70>
# dsplit                       function                      <function dsplit at 0x00000000052B6598>
# dstack                       function                      <function dstack at 0x00000000052B6268>
# dtype                        type                          <class 'numpy.dtype'>
# e                            float                         2.718281828459045
# ediff1d                      function                      <function ediff1d at 0x00000000052CF510>
# eig                          function                      <function eig at 0x00000000052CE7B8>
# eigh                         function                      <function eigh at 0x00000000052CE840>
# eigvals                      function                      <function eigvals at 0x00000000052CE620>
# eigvalsh                     function                      <function eigvalsh at 0x00000000052CE6A8>
# einsum                       function                      <function einsum at 0x0000000004FF0400>
# einsum_path                  function                      <function einsum_path at 0x0000000004FF0378>
# emath                        module                        <module 'numpy.lib.scimat<...>\numpy\\lib\\scimath.py'>
# empty                        builtin_function_or_method    <built-in function empty>
# empty_like                   builtin_function_or_method    <built-in function empty_like>
# entropy                      function                      <function entropy at 0x00000000075E22F0>
# epoch2num                    function                      <function epoch2num at 0x00000000070D31E0>
# equal                        ufunc                         <ufunc 'equal'>
# errorbar                     function                      <function errorbar at 0x000000000E1DD7B8>
# errstate                     type                          <class 'numpy.core.numeric.errstate'>
# euler_gamma                  float                         0.5772156649015329
# eventplot                    function                      <function eventplot at 0x000000000E1DD840>
# exception_to_str             function                      <function exception_to_str at 0x00000000055F8950>
# exp                          ufunc                         <ufunc 'exp'>
# exp2                         ufunc                         <ufunc 'exp2'>
# exp_safe                     function                      <function exp_safe at 0x00000000075E2E18>
# expand_dims                  function                      <function expand_dims at 0x00000000052B6158>
# expm1                        ufunc                         <ufunc 'expm1'>
# exponential                  builtin_function_or_method    <built-in method exponent<...>ct at 0x000000000557D168>
# extract                      function                      <function extract at 0x0000000005294AE8>
# eye                          function                      <function eye at 0x0000000005285620>
# f                            builtin_function_or_method    <built-in method f of mtr<...>ct at 0x000000000557D168>
# fabs                         ufunc                         <ufunc 'fabs'>
# fastCopyAndTranspose         builtin_function_or_method    <built-in function _fastCopyAndTranspose>
# fft                          function                      <function fft at 0x0000000005333620>
# fft2                         function                      <function fft2 at 0x0000000005333B70>
# fftfreq                      function                      <function fftfreq at 0x00000000053331E0>
# fftn                         function                      <function fftn at 0x0000000005333A60>
# fftpack                      module                        <module 'numpy.fft.fftpac<...>\numpy\\fft\\fftpack.py'>
# fftpack_lite                 module                        <module 'numpy.fft.fftpac<...>lite.cp35-win_amd64.pyd'>
# fftshift                     function                      <function fftshift at 0x0000000005333048>
# fftsurr                      function                      <function fftsurr at 0x00000000075E2D08>
# figaspect                    function                      <function figaspect at 0x000000000E0B2D08>
# figimage                     function                      <function figimage at 0x000000000E1D9268>
# figlegend                    function                      <function figlegend at 0x000000000E1D8EA0>
# fignum_exists                function                      <function fignum_exists at 0x000000000E1D89D8>
# figtext                      function                      <function figtext at 0x000000000E1D9158>
# figure                       function                      <function figure at 0x000000000E1D8840>
# fill                         function                      <function fill at 0x000000000E1DD8C8>
# fill_between                 function                      <function fill_between at 0x000000000E1DD950>
# fill_betweenx                function                      <function fill_betweenx at 0x000000000E1DD9D8>
# fill_diagonal                function                      <function fill_diagonal at 0x000000000529EA60>
# find                         function                      <function find at 0x00000000075E2400>
# find_common_type             function                      <function find_common_type at 0x00000000047630D0>
# findobj                      function                      <function findobj at 0x000000000E1D8158>
# finfo                        type                          <class 'numpy.core.getlimits.finfo'>
# fix                          function                      <function fix at 0x0000000005273048>
# flag                         function                      <function flag at 0x000000000E1E0400>
# flatiter                     type                          <class 'numpy.flatiter'>
# flatnonzero                  function                      <function flatnonzero at 0x0000000004F9B510>
# flatten                      function                      <function flatten at 0x00000000055F4F28>
# flexible                     type                          <class 'numpy.flexible'>
# flip                         function                      <function flip at 0x0000000005285D08>
# fliplr                       function                      <function fliplr at 0x0000000005285488>
# flipud                       function                      <function flipud at 0x0000000005285598>
# float16                      type                          <class 'numpy.float16'>
# float32                      type                          <class 'numpy.float32'>
# float64                      type                          <class 'numpy.float64'>
# float_                       type                          <class 'numpy.float64'>
# float_power                  ufunc                         <ufunc 'float_power'>
# floating                     type                          <class 'numpy.floating'>
# floor                        ufunc                         <ufunc 'floor'>
# floor_divide                 ufunc                         <ufunc 'floor_divide'>
# fmax                         ufunc                         <ufunc 'fmax'>
# fmin                         ufunc                         <ufunc 'fmin'>
# fmod                         ufunc                         <ufunc 'fmod'>
# format_parser                type                          <class 'numpy.core.records.format_parser'>
# frange                       function                      <function frange at 0x00000000075E31E0>
# frexp                        ufunc                         <ufunc 'frexp'>
# frombuffer                   builtin_function_or_method    <built-in function frombuffer>
# fromfile                     builtin_function_or_method    <built-in function fromfile>
# fromfunction                 function                      <function fromfunction at 0x0000000004FBA488>
# fromiter                     builtin_function_or_method    <built-in function fromiter>
# frompyfunc                   builtin_function_or_method    <built-in function frompyfunc>
# fromregex                    function                      <function fromregex at 0x00000000052F6AE8>
# fromstring                   builtin_function_or_method    <built-in function fromstring>
# full                         function                      <function full at 0x0000000004F8EEA0>
# full_like                    function                      <function full_like at 0x0000000004F8EF28>
# fv                           function                      <function fv at 0x00000000052F6EA0>
# gamma                        builtin_function_or_method    <built-in method gamma of<...>ct at 0x000000000557D168>
# gca                          function                      <function gca at 0x000000000E1D97B8>
# gcf                          function                      <function gcf at 0x000000000E1D8950>
# gci                          function                      <function gci at 0x000000000E1D8488>
# generic                      type                          <class 'numpy.generic'>
# genfromtxt                   function                      <function genfromtxt at 0x00000000052F6B70>
# geometric                    builtin_function_or_method    <built-in method geometri<...>ct at 0x000000000557D168>
# geomspace                    function                      <function geomspace at 0x0000000004FD9620>
# get                          function                      <function getp at 0x0000000007592C80>
# get_array_wrap               function                      <function get_array_wrap at 0x00000000052B66A8>
# get_backend                  function                      <function get_backend at 0x0000000006C07048>
# get_cmap                     function                      <function get_cmap at 0x00000000075467B8>
# get_current_fig_manager      function                      <function get_current_fig<...>er at 0x000000000E1D8B70>
# get_figlabels                function                      <function get_figlabels at 0x000000000E1D8AE8>
# get_fignums                  function                      <function get_fignums at 0x000000000E1D8A60>
# get_include                  function                      <function get_include at 0x0000000005258268>
# get_plot_commands            function                      <function get_plot_comman<...>ds at 0x000000000E1DA598>
# get_printoptions             function                      <function get_printoptions at 0x0000000004FB80D0>
# get_scale_docs               function                      <function get_scale_docs at 0x000000000E053A60>
# get_scale_names              function                      <function get_scale_names at 0x000000000E041048>
# get_sparse_matrix            function                      <function get_sparse_matr<...>ix at 0x00000000075E2AE8>
# get_state                    builtin_function_or_method    <built-in method get_stat<...>ct at 0x000000000557D168>
# get_xyz_where                function                      <function get_xyz_where at 0x00000000075E2A60>
# getbufsize                   function                      <function getbufsize at 0x0000000004FBABF8>
# geterr                       function                      <function geterr at 0x0000000004FBAAE8>
# geterrcall                   function                      <function geterrcall at 0x0000000004FBAD08>
# geterrobj                    builtin_function_or_method    <built-in function geterrobj>
# getp                         function                      <function getp at 0x0000000007592C80>
# ginput                       function                      <function ginput at 0x000000000E1D9048>
# gradient                     function                      <function gradient at 0x0000000005294620>
# gray                         function                      <function gray at 0x000000000E1E0488>
# greater                      ufunc                         <ufunc 'greater'>
# greater_equal                ufunc                         <ufunc 'greater_equal'>
# grid                         function                      <function grid at 0x000000000E1DEC80>
# griddata                     function                      <function griddata at 0x00000000075E4AE8>
# gumbel                       builtin_function_or_method    <built-in method gumbel o<...>ct at 0x000000000557D168>
# half                         type                          <class 'numpy.float16'>
# hamming                      function                      <function hamming at 0x0000000005295510>
# hanning                      function                      <function hanning at 0x0000000005295488>
# heaviside                    ufunc                         <ufunc 'heaviside'>
# helper                       module                        <module 'numpy.fft.helper<...>\\numpy\\fft\\helper.py'>
# hexbin                       function                      <function hexbin at 0x000000000E1DDA60>
# hfft                         function                      <function hfft at 0x0000000005333840>
# hist                         function                      <function hist at 0x000000000E1DDAE8>
# hist2d                       function                      <function hist2d at 0x000000000E1DDB70>
# histogram                    function                      <function histogram at 0x0000000005294268>
# histogram2d                  function                      <function histogram2d at 0x00000000052859D8>
# histogramdd                  function                      <function histogramdd at 0x00000000052942F0>
# hlines                       function                      <function hlines at 0x000000000E1DDBF8>
# hold                         function                      <function hold at 0x000000000E1D9488>
# hot                          function                      <function hot at 0x000000000E1E0510>
# hsplit                       function                      <function hsplit at 0x00000000052B6488>
# hstack                       function                      <function hstack at 0x0000000004FE9B70>
# hsv                          function                      <function hsv at 0x000000000E1E0598>
# hypergeometric               builtin_function_or_method    <built-in method hypergeo<...>ct at 0x000000000557D168>
# hypot                        ufunc                         <ufunc 'hypot'>
# i0                           function                      <function i0 at 0x0000000005295730>
# identity                     function                      <function identity at 0x0000000004FBA7B8>
# ifft                         function                      <function ifft at 0x00000000053336A8>
# ifft2                        function                      <function ifft2 at 0x0000000005333BF8>
# ifftn                        function                      <function ifftn at 0x0000000005333AE8>
# ifftshift                    function                      <function ifftshift at 0x0000000005333158>
# ihfft                        function                      <function ihfft at 0x00000000053338C8>
# iinfo                        type                          <class 'numpy.core.getlimits.iinfo'>
# imag                         function                      <function imag at 0x0000000005273400>
# imread                       function                      <function imread at 0x000000000E1DAA60>
# imsave                       function                      <function imsave at 0x000000000E1DAAE8>
# imshow                       function                      <function imshow at 0x000000000E1DDC80>
# in1d                         function                      <function in1d at 0x00000000052D08C8>
# index_exp                    IndexExpression               <numpy.lib.index_tricks.I<...>ct at 0x00000000052A11D0>
# indices                      function                      <function indices at 0x0000000004FBA400>
# inexact                      type                          <class 'numpy.inexact'>
# inf                          float                         inf
# inferno                      function                      <function inferno at 0x000000000E1E09D8>
# info                         module                        <module 'numpy.linalg.inf<...>\numpy\\linalg\\info.py'>
# infty                        float                         inf
# inner                        builtin_function_or_method    <built-in function inner>
# insert                       function                      <function insert at 0x0000000005295E18>
# inside_poly                  function                      <function inside_poly at 0x00000000075E4D08>
# install_repl_displayhook     function                      <function install_repl_di<...>ok at 0x000000000E1AF1E0>
# int0                         type                          <class 'numpy.int64'>
# int16                        type                          <class 'numpy.int16'>
# int32                        type                          <class 'numpy.int32'>
# int64                        type                          <class 'numpy.int64'>
# int8                         type                          <class 'numpy.int8'>
# int_                         type                          <class 'numpy.int32'>
# int_asbuffer                 builtin_function_or_method    <built-in function int_asbuffer>
# intc                         type                          <class 'numpy.int32'>
# integer                      type                          <class 'numpy.integer'>
# interactive                  function                      <function interactive at 0x0000000006C070D0>
# interp                       function                      <function interp at 0x0000000005294730>
# intersect1d                  function                      <function intersect1d at 0x00000000052D07B8>
# intp                         type                          <class 'numpy.int64'>
# inv                          function                      <function inv at 0x00000000052CE488>
# invert                       ufunc                         <ufunc 'invert'>
# ioff                         function                      <function ioff at 0x000000000E1D82F0>
# ion                          function                      <function ion at 0x000000000E1D8378>
# ipmt                         function                      <function ipmt at 0x00000000052FD0D0>
# irfft                        function                      <function irfft at 0x00000000053337B8>
# irfft2                       function                      <function irfft2 at 0x0000000005333E18>
# irfftn                       function                      <function irfftn at 0x0000000005333D90>
# ...
# seterrobj                    builtin_function_or_method    <built-in function seterrobj>
# setp                         function                      <function setp at 0x000000000E1D87B8>
# setxor1d                     function                      <function setxor1d at 0x00000000052D0840>
# shape                        function                      <function shape at 0x0000000004FB7268>
# shares_memory                builtin_function_or_method    <built-in function shares_memory>
# short                        type                          <class 'numpy.int16'>
# show                         function                      <function show at 0x000000000E1D81E0>
# show_config                  function                      <function show at 0x0000000004D16400>
# shuffle                      builtin_function_or_method    <built-in method shuffle <...>ct at 0x000000000557D168>
# sign                         ufunc                         <ufunc 'sign'>
# signbit                      ufunc                         <ufunc 'signbit'>
# signedinteger                type                          <class 'numpy.signedinteger'>
# silent_list                  type                          <class 'matplotlib.cbook.silent_list'>
# sin                          ufunc                         <ufunc 'sin'>
# sinc                         function                      <function sinc at 0x0000000005295840>
# single                       type                          <class 'numpy.float32'>
# singlecomplex                type                          <class 'numpy.complex64'>
# sinh                         ufunc                         <ufunc 'sinh'>
# six                          module                        <module 'six' from 'd:\\p<...>\\site-packages\\six.py'>
# size                         function                      <function size at 0x0000000004FB7C80>
# slogdet                      function                      <function slogdet at 0x00000000052CEAE8>
# slopes                       function                      <function slopes at 0x00000000075E4BF8>
# solve                        function                      <function solve at 0x00000000052CE378>
# sometrue                     function                      <function sometrue at 0x0000000004FB7510>
# sort                         function                      <function sort at 0x0000000004FB4BF8>
# sort_complex                 function                      <function sort_complex at 0x00000000052948C8>
# source                       function                      <function source at 0x0000000005258AE8>
# spacing                      ufunc                         <ufunc 'spacing'>
# specgram                     function                      <function specgram at 0x000000000E1DE510>
# spectral                     function                      <function spectral at 0x000000000E1E0BF8>
# split                        function                      <function split at 0x00000000052B6400>
# spring                       function                      <function spring at 0x000000000E1E07B8>
# spy                          function                      <function spy at 0x000000000E1DAD90>
# sqrt                         ufunc                         <ufunc 'sqrt'>
# square                       ufunc                         <ufunc 'square'>
# squeeze                      function                      <function squeeze at 0x0000000004FB4F28>
# stack                        function                      <function stack at 0x0000000004FE9BF8>
# stackplot                    function                      <function stackplot at 0x000000000E1DE598>
# standard_cauchy              builtin_function_or_method    <built-in method standard<...>ct at 0x000000000557D168>
# standard_exponential         builtin_function_or_method    <built-in method standard<...>ct at 0x000000000557D168>
# standard_gamma               builtin_function_or_method    <built-in method standard<...>ct at 0x000000000557D168>
# standard_normal              builtin_function_or_method    <built-in method standard<...>ct at 0x000000000557D168>
# standard_t                   builtin_function_or_method    <built-in method standard<...>ct at 0x000000000557D168>
# std                          function                      <function std at 0x0000000004FB7EA0>
# stem                         function                      <function stem at 0x000000000E1DE620>
# step                         function                      <function step at 0x000000000E1DE6A8>
# stineman_interp              function                      <function stineman_interp at 0x00000000075E4C80>
# str0                         type                          <class 'numpy.str_'>
# str_                         type                          <class 'numpy.str_'>
# streamplot                   function                      <function streamplot at 0x000000000E1DE730>
# string_                      type                          <class 'numpy.bytes_'>
# strpdate2num                 type                          <class 'matplotlib.dates.strpdate2num'>
# style                        module                        <module 'matplotlib.style<...>lib\\style\\__init__.py'>
# subplot                      function                      <function subplot at 0x000000000E1D9840>
# subplot2grid                 function                      <function subplot2grid at 0x000000000E1D9950>
# subplot_tool                 function                      <function subplot_tool at 0x000000000E1D9B70>
# subplots                     function                      <function subplots at 0x000000000E1D98C8>
# subplots_adjust              function                      <function subplots_adjust at 0x000000000E1D9AE8>
# subtract                     ufunc                         <ufunc 'subtract'>
# sum                          function                      <function sum at 0x0000000004FB7400>
# summer                       function                      <function summer at 0x000000000E1E0840>
# suptitle                     function                      <function suptitle at 0x000000000E1D91E0>
# svd                          function                      <function svd at 0x00000000052CE8C8>
# swapaxes                     function                      <function swapaxes at 0x0000000004FB49D8>
# switch_backend               function                      <function switch_backend at 0x000000000E1D80D0>
# sys                          module                        <module 'sys' (built-in)>
# table                        function                      <function table at 0x000000000E1DED90>
# take                         function                      <function take at 0x0000000004FB4730>
# tan                          ufunc                         <ufunc 'tan'>
# tanh                         ufunc                         <ufunc 'tanh'>
# tensordot                    function                      <function tensordot at 0x0000000004F9B7B8>
# tensorinv                    function                      <function tensorinv at 0x00000000052CE400>
# tensorsolve                  function                      <function tensorsolve at 0x00000000052CE2F0>
# test                         method                        <bound method NoseTester.<...>t at 0x00000000052BE748>>
# text                         function                      <function text at 0x000000000E1DEE18>
# thetagrids                   function                      <function thetagrids at 0x000000000E1DA488>
# tick_params                  function                      <function tick_params at 0x000000000E1E00D0>
# ticklabel_format             function                      <function ticklabel_format at 0x000000000E1DEF28>
# tight_layout                 function                      <function tight_layout at 0x000000000E1D9BF8>
# tile                         function                      <function tile at 0x00000000052B67B8>
# timedelta64                  type                          <class 'numpy.timedelta64'>
# title                        function                      <function title at 0x000000000E1D9D08>
# trace                        function                      <function trace at 0x0000000004FB70D0>
# tracemalloc_domain           int                           389047
# transpose                    function                      <function transpose at 0x0000000004FB4A60>
# trapz                        function                      <function trapz at 0x0000000005295BF8>
# tri                          function                      <function tri at 0x00000000052857B8>
# triangular                   builtin_function_or_method    <built-in method triangul<...>ct at 0x000000000557D168>
# tricontour                   function                      <function tricontour at 0x000000000E1DE7B8>
# tricontourf                  function                      <function tricontourf at 0x000000000E1DE840>
# tril                         function                      <function tril at 0x0000000005285840>
# tril_indices                 function                      <function tril_indices at 0x0000000005285AE8>
# tril_indices_from            function                      <function tril_indices_fr<...>om at 0x0000000005285B70>
# trim_zeros                   function                      <function trim_zeros at 0x0000000005294950>
# tripcolor                    function                      <function tripcolor at 0x000000000E1DE8C8>
# triplot                      function                      <function triplot at 0x000000000E1DE950>
# triu                         function                      <function triu at 0x00000000052858C8>
# triu_indices                 function                      <function triu_indices at 0x0000000005285BF8>
# triu_indices_from            function                      <function triu_indices_fr<...>om at 0x0000000005285C80>
# true_divide                  ufunc                         <ufunc 'true_divide'>
# trunc                        ufunc                         <ufunc 'trunc'>
# twinx                        function                      <function twinx at 0x000000000E1D99D8>
# twiny                        function                      <function twiny at 0x000000000E1D9A60>
# typeDict                     dict                          n=151
# typeNA                       dict                          n=82
# typecodes                    dict                          n=9
# typename                     function                      <function typename at 0x00000000052738C8>
# types                        module                        <module 'types' from 'd:\<...>python35\\lib\\types.py'>
# ubyte                        type                          <class 'numpy.uint8'>
# ufunc                        type                          <class 'numpy.ufunc'>
# uint                         type                          <class 'numpy.uint32'>
# uint0                        type                          <class 'numpy.uint64'>
# uint16                       type                          <class 'numpy.uint16'>
# uint32                       type                          <class 'numpy.uint32'>
# uint64                       type                          <class 'numpy.uint64'>
# uint8                        type                          <class 'numpy.uint8'>
# uintc                        type                          <class 'numpy.uint32'>
# uintp                        type                          <class 'numpy.uint64'>
# ulonglong                    type                          <class 'numpy.uint64'>
# unicode                      type                          <class 'str'>
# unicode_                     type                          <class 'numpy.str_'>
# unicode_literals             _Feature                      _Feature((2, 6, 0, 'alpha<...>, 0, 'alpha', 0), 131072)
# uniform                      builtin_function_or_method    <built-in method uniform <...>ct at 0x000000000557D168>
# uninstall_repl_displayhook   function                      <function uninstall_repl_<...>ok at 0x000000000E1D8048>
# union1d                      function                      <function union1d at 0x00000000052D09D8>
# unique                       function                      <function unique at 0x00000000052D06A8>
# unpackbits                   builtin_function_or_method    <built-in function unpackbits>
# unravel_index                builtin_function_or_method    <built-in function unravel_index>
# unsignedinteger              type                          <class 'numpy.unsignedinteger'>
# unwrap                       function                      <function unwrap at 0x0000000005294840>
# ushort                       type                          <class 'numpy.uint16'>
# vander                       function                      <function vander at 0x0000000005285950>
# var                          function                      <function var at 0x0000000004FB7F28>
# vdot                         builtin_function_or_method    <built-in function vdot>
# vector_lengths               function                      <function vector_lengths at 0x00000000075E5378>
# vectorize                    type                          <class 'numpy.lib.function_base.vectorize'>
# violinplot                   function                      <function violinplot at 0x000000000E1DE9D8>
# viridis                      function                      <function viridis at 0x000000000E1E0AE8>
# vlines                       function                      <function vlines at 0x000000000E1DEA60>
# void                         type                          <class 'numpy.void'>
# void0                        type                          <class 'numpy.void'>
# vonmises                     builtin_function_or_method    <built-in method vonmises<...>ct at 0x000000000557D168>
# vsplit                       function                      <function vsplit at 0x00000000052B6510>
# vstack                       function                      <function vstack at 0x0000000004FE9AE8>
# waitforbuttonpress           function                      <function waitforbuttonpr<...>ss at 0x000000000E1D90D0>
# wald                         builtin_function_or_method    <built-in method wald of <...>ct at 0x000000000557D168>
# warnings                     module                        <module 'warnings' from '<...>hon35\\lib\\warnings.py'>
# weibull                      builtin_function_or_method    <built-in method weibull <...>ct at 0x000000000557D168>
# where                        builtin_function_or_method    <built-in function where>
# who                          function                      <function who at 0x0000000005258840>
# window_hanning               function                      <function window_hanning at 0x00000000075B0BF8>
# window_none                  function                      <function window_none at 0x00000000075B0D90>
# winter                       function                      <function winter at 0x000000000E1E08C8>
# xcorr                        function                      <function xcorr at 0x000000000E1DEAE8>
# xkcd                         function                      <function xkcd at 0x000000000E1D8730>
# xlabel                       function                      <function xlabel at 0x000000000E1D9E18>
# xlim                         function                      <function xlim at 0x000000000E1D9F28>
# xscale                       function                      <function xscale at 0x000000000E1DA0D0>
# xticks                       function                      <function xticks at 0x000000000E1DA1E0>
# ylabel                       function                      <function ylabel at 0x000000000E1D9EA0>
# ylim                         function                      <function ylim at 0x000000000E1DA048>
# yscale                       function                      <function yscale at 0x000000000E1DA158>
# yticks                       function                      <function yticks at 0x000000000E1DA268>
# zeros                        builtin_function_or_method    <built-in function zeros>
# zeros_like                   function                      <function zeros_like at 0x0000000004F8EBF8>
# zipf                         builtin_function_or_method    <built-in method zipf of <...>ct at 0x000000000557D168>

# %%
# %pwd
# Out:
# 'D:\\Front_End\\py_basic\\scientific_cal'
